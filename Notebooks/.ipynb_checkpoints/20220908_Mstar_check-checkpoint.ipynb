# %%
import os
import sys
sys.path.append('../')
sys.path.append('../datasets')
sys.path.append('../models')
import torch
import torchvision
import torch.backends.cudnn as cudnn
import random
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from importlib import reload
from datasets.three_dim_shapes import ThreeDimShapesDataset
from datasets.small_norb import SmallNORBDataset
from datasets.seq_mnist import SequentialMNIST
import models.seqae as seqae
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from datasets import so3_data as so3d
from einops import rearrange
from sklearn.metrics import r2_score
import pdb
from einops import rearrange
from utils import evaluations as ev

import copy

import csv
import ast
from source import yaml_utils as yu


from tqdm import tqdm

if torch.cuda.is_available():
    device = torch.device('cuda')
    cudnn.deterministic = True
    cudnn.benchmark = True
else:
    device = torch.device('cpu')
    gpu_index = -1


    
    

def iter_list(log_dir):
    dirlist = os.listdir(log_dir)
    iterlist = []
    for mydir in dirlist:
        if 'iter' in mydir and 'tmp' not in mydir:
            iterlist.append(int(mydir.split('_')[-1]))
    return np.array(iterlist)
    
    
def load_model(model, log_dir, iters, latest=False):
    print(f"""{log_dir} \n snapshot_model_iter_{iters}""")
    if latest == True:
        iters = np.max(iter_list(log_dir))
    model.load_state_dict(torch.load(os.path.join(log_dir, 'snapshot_model_iter_{}'.format(iters))))
    #model.load_state_dict(torch.load(os.path.join(log_dir, 'snapshot_manager_iter_{}'.format(iters))))




def load_config(targdir_path):
    targ_config_path = os.path.join(targdir_path, 'config.yml')
    with open(targ_config_path, 'r') as f:
        config = yaml.safe_load(f)
    return config
    
    
def filter_names(query, mydict):
    filtered = {} 
    for key in mydict.keys():
        if query in key:
            filtered[key] = mydict[key]
    return filtered
    
def filter_list(query, mylist):
    filtered = [] 
    for key in mylist:
        if query in key:
            filtered.append(key)
    return filtered


def model_exists(targlist,  targpath):
    filtered_list = []
    for targdir in targlist:
        if os.path.exists(os.path.join(targpath, targdir, 'config.yml')):
            filtered_list.append(targdir)
    return filtered_list
    
    
from utils import yaml_utils as yu
import yaml
rootpath = '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/'
result_dir = '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result'
jobdir = '/mnt/vol21/masomatics/ULASclone/jobs'

mode = 'so3'
dat_root = f"""/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/datasets/{mode}"""

baseline_path = os.path.join(result_dir, '20220615_default_run_mnist')
basestar_path = os.path.join(result_dir, '20220615_NeuralMstar_neuralM_vanilla')
print(baseline_path)
print(os.path.exists(baseline_path))
print(os.path.exists(basestar_path))


filter_list('202209', os.listdir(result_dir))
# Out:
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_default_run_mnist
# True
# True
# ['20220901_Mstar_inv_reg_cnn_0',
#  '20220909_latentPredict_zero_0',
#  '20220908_latentPredict_bg_0',
#  '20220901_Mstar_orth_0',
#  '20220907_latentPredict_0']

# %%
projname = 'latentPredict'
setting_name = '_'.join(np.sort(filter_list(projname, os.listdir(jobdir)))[0].split('_')[:-1])
print(setting_name)
filter_list(projname, os.listdir(result_dir))
# Out:
# 20220906
# ['20220909_latentPredict_zero_0',
#  '20220908_latentPredict_bg_0',
#  '20220907_latentPredict_0']

# %%
#targdir = '20220824_MstarRemoveXa_0' 
#targdir = '20220826_Mstar_orth_0'
#targdir = '20220830_Mstar_orth_0'
#targdir  =  '20220829_Mstar_inv_reg_cnn_0'

#projname = 'Mstar_orth_mlp_two' 
targdir = f'''20220907_{projname}_0'''
#jobpath =f'''../jobs/20220829_{projname}'''
jobpath = f'''../jobs/{setting_name}_{projname}'''
print(jobpath)
print(os.path.exists(jobpath))
#jobpath = os.path.join('../jobs/','_'.join(targdir.split('_')[:-1]))


targpath = os.path.join(result_dir, targdir)
targlist = os.listdir(targpath)

targlist = model_exists(targlist,  targpath)
print(targlist)
# Out:
# ../jobs/20220906_latentPredict
# True
# ['reg_latent2_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent005_reg_obs0_dmodedefault_predictiveFalse', 'reg_latent01_reg_obs10_dmodeplainh_predictiveTrue', 'reg_latent1_reg_obs0_dmodeplainh_predictiveFalse', 'reg_latent2_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent01_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent01_reg_obs0_dmodedefault_predictiveFalse', 'reg_latent1_reg_obs10_dmodeplainh_predictiveFalse', 'reg_latent005_reg_obs10_dmodedefault_predictiveTrue', 'reg_latent1_reg_obs10_dmodeplainh_predictiveTrue', 'reg_latent005_reg_obs10_dmodeplainh_predictiveTrue', 'reg_latent01_reg_obs0_dmodeplainh_predictiveFalse', 'reg_latent2_reg_obs0_dmodeplainh_predictiveFalse', 'reg_latent01_reg_obs10_dmodedefault_predictiveTrue', 'reg_latent005_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent1_reg_obs10_dmodedefault_predictiveTrue', 'reg_latent005_reg_obs10_dmodeplainh_predictiveFalse', 'reg_latent01_reg_obs0_dmodedefault_predictiveTrue', 'reg_latent1_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent2_reg_obs0_dmodedefault_predictiveTrue', 'reg_latent01_reg_obs10_dmodeplainh_predictiveFalse', 'reg_latent1_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent1_reg_obs0_dmodedefault_predictiveFalse', 'reg_latent005_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent01_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent1_reg_obs0_dmodedefault_predictiveTrue', 'reg_latent005_reg_obs0_dmodedefault_predictiveTrue']

# %%
print(os.listdir(targpath))

resultlist = os.listdir(targpath)



from utils import notebook_utils as nb
reload(nb)



for result in resultlist:
    studypath = os.path.join(targpath, result)
    history = nb.read_history(studypath)
    if len(history) > 0:
        plt.plot(history['iteration'], history['train/loss'], label = result)
        print(history['train/loss'][-1])
plt.legend(bbox_to_anchor=(1.05, 1))
plt.savefig(os.path.join(jobpath, f"""{targdir}_learning.png"""))
# Out:
# ['reg_latent2_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent005_reg_obs0_dmodedefault_predictiveFalse', 'reg_latent01_reg_obs10_dmodeplainh_predictiveTrue', 'reg_latent1_reg_obs0_dmodeplainh_predictiveFalse', 'reg_latent2_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent01_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent01_reg_obs0_dmodedefault_predictiveFalse', 'reg_latent1_reg_obs10_dmodeplainh_predictiveFalse', 'reg_latent005_reg_obs10_dmodedefault_predictiveTrue', 'reg_latent1_reg_obs10_dmodeplainh_predictiveTrue', 'reg_latent005_reg_obs10_dmodeplainh_predictiveTrue', 'reg_latent01_reg_obs0_dmodeplainh_predictiveFalse', 'reg_latent2_reg_obs0_dmodeplainh_predictiveFalse', 'reg_latent01_reg_obs10_dmodedefault_predictiveTrue', 'reg_latent005_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent1_reg_obs10_dmodedefault_predictiveTrue', 'reg_latent005_reg_obs10_dmodeplainh_predictiveFalse', 'reg_latent01_reg_obs0_dmodedefault_predictiveTrue', 'reg_latent1_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent2_reg_obs0_dmodedefault_predictiveTrue', 'reg_latent01_reg_obs10_dmodeplainh_predictiveFalse', 'reg_latent1_reg_obs0_dmodeplainh_predictiveTrue', 'reg_latent1_reg_obs0_dmodedefault_predictiveFalse', 'reg_latent005_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent01_reg_obs10_dmodedefault_predictiveFalse', 'reg_latent1_reg_obs0_dmodedefault_predictiveTrue', 'reg_latent005_reg_obs0_dmodedefault_predictiveTrue']
# 178.336772605896
# 0.7423768064975739
# 116.35767934036255
# 56.417753108978275
# 1.036415357351303
# 0.7094253140091896
# 0.9370417467951775
# 216.86637755584718
# 95.7578102645874
# 117.54580570220948
# 117.94709447479248
# 0.8933371517062187
# 56.41884950637817
# 101.25452001571655
# 0.5697180244326592
# 108.28386006164551
# 194.94109691619872
# 0.6965427607297897
# 174.0974397201538
# 56.41835105895996
# 194.19608953857423
# 0.8702190859913826
# 56.41879308700562
# 152.17844156646728
# 157.15540644836426
# 18.58344022369385
# 0.6097273481190204

# %%
reload(ev)
results = {} 
inferred_Ms = {} 
model_configs = {}
models = {}
tp = 8
n_cond = 2
device =0
predictive = False
reconstructive = False

targdir_pathlist = [os.path.join(targpath, targdir) for targdir in targlist] 
#targdir_pathlist = []
targdir_pathlist.append(basestar_path)
targdir_pathlist.append(baseline_path)


for targdir_path in targdir_pathlist:
    
    Mlist = [] 
    config = load_config(targdir_path)
    
    dataconfig = config['train_data']
    dataconfig['args']['T'] = tp + n_cond
    
    data = yu.load_component(dataconfig)
    train_loader = DataLoader(data, 
                              batch_size=config['batchsize'],
                              shuffle=True,
                              num_workers=config['num_workers'])

    model_config = config['model']
    model = yu.load_component(model_config)
    iterlist = iter_list(targdir_path)
    if len(iterlist) == 0:
        print(f"""There is no model trained for {targdir_path}""")
    else:
        maxiter = np.max(iter_list(targdir_path))
        load_model(model, targdir_path, maxiter)
        model = model.eval().to(device)

        images = iter(train_loader).next()

        # Initialize lazy modules
        if type(images) == list:
            images = torch.stack(images)
            images = images.transpose(1, 0)        
        images = images.to(device)
        if str(type(model)).split(' ')[-1].split('.')[-1].split("'")[0] == 'SeqAENeuralM_latentPredict':
            model.conduct_prediction(images[:, :n_cond], n_rolls=tp)
        else:
            model(images[:, :n_cond])
            
            
        with torch.no_grad():
            scores = [] 
            l2scores = []
            for images in tqdm(train_loader):
                if type(images) == list:
                    images = torch.stack(images)
                    images = images.transpose(1, 0)
                # n t c w h
                images = images.to(device)
                images_cond = images[:, :n_cond]
                if predictive == True or reconctructive == True:
                    images_target = images
                else:
                    images_target = images[:, n_cond:n_cond+tp]
                x_next, M = ev.predict(images, model, n_cond=n_cond, tp=tp, device=device, predictive=predictive)
 
                r2_losses = [] 
                l2_losses = []
                for k in range(tp):
                    
                    images_target_vec = rearrange(images_target, 'n t c w h -> n t (c w h)')
                    x_next_vec = rearrange(x_next, 'n t c w h -> n t (c w h)')
                    #r2_loss_t = r2_score(images_target_vec[:,k].to('cpu').numpy(), x_next_vec[:,k].to('cpu').numpy()) 
                    l2_loss_t = torch.sqrt(torch.sum((images_target[:, k].to('cpu') - x_next[:, k].to('cpu'))**2, axis=[1,2,3]))
                    l2_loss_t = torch.mean(l2_loss_t)
                    #r2_losses.append(r2_loss_t)
                    l2_losses.append(l2_loss_t)

                scores.append(torch.tensor(r2_losses))
                l2scores.append(torch.tensor(l2_losses))

                Mlist.append(M)
        
                
        Mlist = torch.cat(Mlist)       
        scores = torch.stack(scores)
        #av_score = torch.mean(scores, axis=0)
        #av_var = torch.var(scores, axis=0)
        
        l2scores = torch.stack(l2scores)
        av_l2 = torch.mean(l2scores, axis=0)
        av_l2var = torch.var(l2scores, axis=0)
        print(av_l2)
        
        #results[targdir_path] = [av_score, av_var, av_l2, av_l2var]
        results[targdir_path] = [av_l2, av_l2var]


        inferred_Ms[targdir_path] = Mlist
        models[targdir_path] = model.to('cpu')
        model_configs[targdir_path] = model_config
# Out:
# /usr/local/lib/python3.8/site-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs10_dmodedefault_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.16it/s]
# tensor([0.0000, 1.2417, 2.0275, 8.0105, 9.1271, 9.5409, 9.4669, 9.6061])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs0_dmodedefault_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.45it/s]
# tensor([ 0.0000,  5.5270,  6.2041,  8.1790, 10.3068, 11.5917, 12.0940, 12.7590])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodeplainh_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:23<00:00,  7.85it/s]
# tensor([0.0000, 4.8377, 7.0815, 8.3127, 8.5065, 8.5672, 8.7855, 8.9580])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodeplainh_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:22<00:00,  8.12it/s]
# tensor([0.0000, 7.3592, 7.3115, 7.2943, 7.2567, 7.2543, 7.2651, 7.3340])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs0_dmodeplainh_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:22<00:00,  8.01it/s]
# tensor([0.0000, 7.5424, 8.8099, 9.1459, 8.9834, 8.9575, 9.1098, 9.2499])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodeplainh_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:22<00:00,  7.97it/s]
# tensor([0.0000, 6.7062, 7.5130, 6.9757, 8.6481, 9.4833, 9.5782, 9.4181])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodedefault_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.44it/s]
# tensor([ 0.0000,  3.2419,  3.9395,  7.7369,  9.4471, 10.1150, 10.1200, 10.2915])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodeplainh_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:22<00:00,  7.99it/s]
# tensor([0.0000, 1.3583, 2.5006, 6.4350, 7.6599, 8.3076, 8.7171, 8.9289])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.44it/s]
# tensor([0.0000, 2.0973, 3.8122, 5.5963, 6.6961, 7.3174, 7.7620, 8.1431])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodeplainh_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:22<00:00,  7.99it/s]
# tensor([0.0000, 5.0897, 6.6944, 7.4110, 7.8144, 7.9746, 8.1028, 8.1065])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodeplainh_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:22<00:00,  7.99it/s]
# tensor([0.0000, 4.4263, 5.6005, 7.0183, 8.0955, 8.5694, 8.8139, 9.0474])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodeplainh_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:24<00:00,  7.59it/s]
# tensor([ 0.0000,  3.7710,  4.9865,  8.2058,  9.8308, 10.5823, 10.7450, 11.0377])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs0_dmodeplainh_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:23<00:00,  7.94it/s]
# tensor([0.0000, 7.3450, 7.3264, 7.2957, 7.2628, 7.2453, 7.2797, 7.3106])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.35it/s]
# tensor([0.0000, 2.1173, 3.7425, 5.4926, 6.6176, 7.3107, 7.8609, 8.2609])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs0_dmodeplainh_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:23<00:00,  7.85it/s]
# tensor([0.0000, 8.0614, 7.6950, 7.8443, 8.3088, 8.5586, 8.4875, 8.3867])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.27it/s]
# tensor([0.0000, 4.9305, 4.8102, 5.0509, 7.2148, 8.4295, 8.6020, 8.4751])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodeplainh_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:23<00:00,  7.90it/s]
# tensor([0.0000, 1.2526, 2.3641, 6.1345, 7.6671, 8.4488, 8.9115, 9.2213])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.25it/s]
# tensor([0.0000, 7.6695, 6.5895, 6.4558, 7.6494, 8.3352, 8.3644, 8.2224])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodedefault_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.30it/s]
# tensor([0.0000, 1.2849, 2.2598, 7.7894, 9.1472, 9.5838, 9.5097, 9.5694])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs0_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.30it/s]
# tensor([0.0000, 7.3512, 7.2912, 7.2940, 7.2689, 7.2370, 7.2882, 7.3035])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodeplainh_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:23<00:00,  7.88it/s]
# tensor([0.0000, 1.3152, 2.4820, 6.0886, 7.6155, 8.4218, 8.8929, 9.2066])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodeplainh_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:23<00:00,  7.84it/s]
# tensor([0.0000, 7.0116, 8.5119, 8.7703, 8.8344, 8.9533, 9.1723, 9.2746])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodedefault_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.27it/s]
# tensor([0.0000, 7.3277, 7.3126, 7.2836, 7.2283, 7.2484, 7.2741, 7.3100])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodedefault_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.19it/s]
# tensor([0.0000, 1.1247, 2.1136, 7.0614, 8.8848, 9.3247, 9.2998, 9.3549])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodedefault_predictiveFalse
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.20it/s]
# tensor([0.0000, 1.1600, 2.1254, 6.8151, 8.7742, 9.2935, 9.3259, 9.3929])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:19<00:00,  9.20it/s]
# tensor([0.0000, 6.8162, 7.6068, 8.5731, 9.1390, 9.4502, 9.6877, 9.9082])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs0_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:20<00:00,  9.15it/s]
# tensor([0.0000, 8.1907, 7.0662, 6.9130, 7.8122, 8.3096, 8.2952, 8.1570])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_NeuralMstar_neuralM_vanilla
#  snapshot_model_iter_50000
# 100%|██████████| 183/183 [00:11<00:00, 15.72it/s]
# tensor([0.0000, 4.5204, 4.5119, 6.7238, 8.3365, 8.9961, 9.3660, 9.6942])
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_default_run_mnist
#  snapshot_model_iter_50000
# 100%|██████████| 183/183 [00:11<00:00, 16.52it/s]
# tensor([0.0000, 2.1936, 3.2694, 5.1241, 6.6403, 7.5300, 8.1103, 8.5426])

# %%
results
# Out:
# {'/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs10_dmodedefault_predictiveFalse': [tensor([0.0000, 1.2417, 2.0275, 8.0105, 9.1271, 9.5409, 9.4669, 9.6061]),
#   tensor([0.0000, 0.0050, 0.0314, 0.1218, 0.1527, 0.1583, 0.1335, 0.1249])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs0_dmodedefault_predictiveFalse': [tensor([ 0.0000,  5.5270,  6.2041,  8.1790, 10.3068, 11.5917, 12.0940, 12.7590]),
#   tensor([0.0000, 0.0916, 0.0716, 0.1465, 0.3472, 0.3758, 0.3471, 0.3668])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodeplainh_predictiveTrue': [tensor([0.0000, 4.8377, 7.0815, 8.3127, 8.5065, 8.5672, 8.7855, 8.9580]),
#   tensor([0.0000, 0.1040, 0.1863, 0.1830, 0.1484, 0.1512, 0.1449, 0.1312])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodeplainh_predictiveFalse': [tensor([0.0000, 7.3592, 7.3115, 7.2943, 7.2567, 7.2543, 7.2651, 7.3340]),
#   tensor([0.0000, 0.0781, 0.0743, 0.0864, 0.0734, 0.0747, 0.0792, 0.0867])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs0_dmodeplainh_predictiveTrue': [tensor([0.0000, 7.5424, 8.8099, 9.1459, 8.9834, 8.9575, 9.1098, 9.2499]),
#   tensor([0.0000, 0.1035, 0.1350, 0.1247, 0.1118, 0.1092, 0.1114, 0.1111])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodeplainh_predictiveTrue': [tensor([0.0000, 6.7062, 7.5130, 6.9757, 8.6481, 9.4833, 9.5782, 9.4181]),
#   tensor([0.0000, 0.3039, 0.1606, 0.1395, 0.1438, 0.1681, 0.1197, 0.1220])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodedefault_predictiveFalse': [tensor([ 0.0000,  3.2419,  3.9395,  7.7369,  9.4471, 10.1150, 10.1200, 10.2915]),
#   tensor([0.0000, 0.0905, 0.0853, 0.2037, 0.2131, 0.2029, 0.2109, 0.1955])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodeplainh_predictiveFalse': [tensor([0.0000, 1.3583, 2.5006, 6.4350, 7.6599, 8.3076, 8.7171, 8.9289]),
#   tensor([0.0000, 0.0052, 0.0556, 0.2191, 0.1580, 0.1226, 0.1173, 0.1213])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodedefault_predictiveTrue': [tensor([0.0000, 2.0973, 3.8122, 5.5963, 6.6961, 7.3174, 7.7620, 8.1431]),
#   tensor([0.0000, 0.0710, 0.1377, 0.1681, 0.1531, 0.1323, 0.1165, 0.1037])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodeplainh_predictiveTrue': [tensor([0.0000, 5.0897, 6.6944, 7.4110, 7.8144, 7.9746, 8.1028, 8.1065]),
#   tensor([0.0000, 0.1333, 0.1607, 0.1477, 0.1355, 0.1162, 0.1060, 0.1014])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodeplainh_predictiveTrue': [tensor([0.0000, 4.4263, 5.6005, 7.0183, 8.0955, 8.5694, 8.8139, 9.0474]),
#   tensor([0.0000, 0.1341, 0.1633, 0.1541, 0.1476, 0.1491, 0.1476, 0.1352])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodeplainh_predictiveFalse': [tensor([ 0.0000,  3.7710,  4.9865,  8.2058,  9.8308, 10.5823, 10.7450, 11.0377]),
#   tensor([0.0000, 0.0713, 0.0872, 0.1482, 0.2066, 0.1952, 0.1745, 0.1792])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs0_dmodeplainh_predictiveFalse': [tensor([0.0000, 7.3450, 7.3264, 7.2957, 7.2628, 7.2453, 7.2797, 7.3106]),
#   tensor([0.0000, 0.0621, 0.0671, 0.0607, 0.0641, 0.0633, 0.0600, 0.0602])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodedefault_predictiveTrue': [tensor([0.0000, 2.1173, 3.7425, 5.4926, 6.6176, 7.3107, 7.8609, 8.2609]),
#   tensor([0.0000, 0.0511, 0.1305, 0.1362, 0.1226, 0.1418, 0.1451, 0.1348])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs0_dmodeplainh_predictiveTrue': [tensor([0.0000, 8.0614, 7.6950, 7.8443, 8.3088, 8.5586, 8.4875, 8.3867]),
#   tensor([0.0000, 0.2483, 0.1413, 0.1376, 0.1177, 0.1077, 0.1052, 0.1002])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodedefault_predictiveTrue': [tensor([0.0000, 4.9305, 4.8102, 5.0509, 7.2148, 8.4295, 8.6020, 8.4751]),
#   tensor([0.0000, 0.4628, 0.1634, 0.2149, 0.1822, 0.1609, 0.1360, 0.1311])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodeplainh_predictiveFalse': [tensor([0.0000, 1.2526, 2.3641, 6.1345, 7.6671, 8.4488, 8.9115, 9.2213]),
#   tensor([0.0000, 0.0036, 0.0388, 0.1629, 0.1114, 0.1168, 0.1153, 0.1252])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs0_dmodedefault_predictiveTrue': [tensor([0.0000, 7.6695, 6.5895, 6.4558, 7.6494, 8.3352, 8.3644, 8.2224]),
#   tensor([0.0000, 0.2179, 0.0970, 0.1339, 0.0963, 0.1180, 0.1113, 0.1088])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodedefault_predictiveFalse': [tensor([0.0000, 1.2849, 2.2598, 7.7894, 9.1472, 9.5838, 9.5097, 9.5694]),
#   tensor([0.0000, 0.0055, 0.0520, 0.1223, 0.1377, 0.1336, 0.1323, 0.1344])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent2_reg_obs0_dmodedefault_predictiveTrue': [tensor([0.0000, 7.3512, 7.2912, 7.2940, 7.2689, 7.2370, 7.2882, 7.3035]),
#   tensor([0.0000, 0.0712, 0.0644, 0.0634, 0.0672, 0.0624, 0.0629, 0.0644])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodeplainh_predictiveFalse': [tensor([0.0000, 1.3152, 2.4820, 6.0886, 7.6155, 8.4218, 8.8929, 9.2066]),
#   tensor([0.0000, 0.0044, 0.0432, 0.2136, 0.1657, 0.1441, 0.1533, 0.1443])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodeplainh_predictiveTrue': [tensor([0.0000, 7.0116, 8.5119, 8.7703, 8.8344, 8.9533, 9.1723, 9.2746]),
#   tensor([0.0000, 0.1193, 0.1396, 0.1309, 0.1092, 0.1155, 0.1335, 0.1258])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodedefault_predictiveFalse': [tensor([0.0000, 7.3277, 7.3126, 7.2836, 7.2283, 7.2484, 7.2741, 7.3100]),
#   tensor([0.0000, 0.0793, 0.0973, 0.0808, 0.0780, 0.0772, 0.0767, 0.0776])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodedefault_predictiveFalse': [tensor([0.0000, 1.1247, 2.1136, 7.0614, 8.8848, 9.3247, 9.2998, 9.3549]),
#   tensor([0.0000, 0.0035, 0.0362, 0.1316, 0.1096, 0.1263, 0.1352, 0.1272])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodedefault_predictiveFalse': [tensor([0.0000, 1.1600, 2.1254, 6.8151, 8.7742, 9.2935, 9.3259, 9.3929]),
#   tensor([0.0000, 0.0031, 0.0346, 0.1287, 0.1382, 0.1251, 0.1326, 0.1313])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs0_dmodedefault_predictiveTrue': [tensor([0.0000, 6.8162, 7.6068, 8.5731, 9.1390, 9.4502, 9.6877, 9.9082]),
#   tensor([0.0000, 0.0924, 0.1300, 0.1786, 0.1542, 0.1389, 0.1269, 0.1472])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs0_dmodedefault_predictiveTrue': [tensor([0.0000, 8.1907, 7.0662, 6.9130, 7.8122, 8.3096, 8.2952, 8.1570]),
#   tensor([0.0000, 0.2596, 0.1540, 0.1223, 0.1142, 0.1281, 0.1039, 0.1166])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_NeuralMstar_neuralM_vanilla': [tensor([0.0000, 4.5204, 4.5119, 6.7238, 8.3365, 8.9961, 9.3660, 9.6942]),
#   tensor([0.0000, 0.1492, 0.1240, 0.1380, 0.1449, 0.1526, 0.1824, 0.2498])],
#  '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_default_run_mnist': [tensor([0.0000, 2.1936, 3.2694, 5.1241, 6.6403, 7.5300, 8.1103, 8.5426]),
#   tensor([0.0000, 0.0144, 0.0406, 0.1064, 0.1273, 0.1293, 0.1106, 0.1101])]}

# %%
images.shape
# Out:
# torch.Size([18, 10, 3, 32, 32])

# %%
reload(nb)
showresults = []
showresults = nb.filter_queries(['predictiveTrue', 'default', 'reg_obs10'] , list(results.keys()))
showresults.append(baseline_path)
showresults.append(basestar_path)


for mode in showresults:
    plt.plot(results[mode][0], label=mode.split('/')[-1])
    plt.xlabel("tp")
plt.legend(bbox_to_anchor=(1.05, 1))
plt.title("Prediction Error")

plt.savefig(os.path.join(jobpath, targdir+'l2loss.png'))

# %%
reload(ev)


def get_predict(targdir_path, swap=False, predictive=False):
    config = load_config(targdir_path)

    model_config = config['model']
    if len(iter_list(targdir_path)) > 0:
        maxiter = np.max(iter_list(targdir_path))
        model = yu.load_component(model_config).to(device)
        load_model(model, targdir_path, maxiter)
        model = model.eval().to(device)
        #model(images[:, :2])
        if str(type(model)).split(' ')[-1].split('.')[-1].split("'")[0] == 'SeqAENeuralM_latentPredict':
            model.conduct_prediction(images[:, :n_cond], n_rolls=tp)
        else:
            model(images[:, :n_cond])
        x_next, M = ev.predict(images, model, n_cond=n_cond, tp=tp, device=device, swap=swap, 
                              predictive=predictive)
        return x_next,M 
    else:
        return 0, 0

# %%
from models import seqae
import models
print(seqae.SeqAELSTSQ)
str(type(model)).split(' ')[-1].split('.')[-1].split("'")[0]
# Out:
# <class 'models.seqae.SeqAELSTSQ'>
# 'SeqAELSTSQ'

# %%
tp=8
idx = 0
predictive = True

images = data[idx]
if type(images) == list:
    images = torch.stack(images)
    images = images.unsqueeze(0)   
    images= images.to(device)

if predictive == True:
    images_target = images
else:
    images_target = images[:, n_cond:n_cond+tp]
    
plt.figure(figsize=(10,2))
for k in range(0,tp):
    plt.subplot(1,tp, k+1)
    plt.imshow(images_target[0][k].detach().to('cpu').permute([1,2, 0]))
    
plt.suptitle("original_target")
plt.savefig(os.path.join(jobpath, f"""{targdir}_realization_original.png"""))

#for j in range(len(targdir_pathlist)):'
for j in range(len(showresults)):
    #x_next, M = get_predict(targdir_pathlist[j], predictive=predictive)
    x_next, M = get_predict(showresults[j], predictive=predictive)
    if type(x_next) == int:
        pass
    else:
        #name = targdir_pathlist[j].split('/')[-1]
        name = showresults[j].split('/')[-1]
        err=0
        plt.figure(figsize=(10,2))
        for k in range(0,tp): 
            plt.subplot(1,tp, k+1)
            plt.imshow(x_next[0][k].detach().to('cpu').permute([1,2, 0]))
            err = err + torch.sqrt(torch.sum((x_next[0][k].to('cpu') - images_target[0][k].to('cpu'))**2))
        err = err / (k+1)
        plt.suptitle(f"""{name}: time_meanerr {err}""")
        plt.savefig(os.path.join(jobpath, f"""{targdir}_realization_{name}.png"""))

# x_next, M = get_predict(targlist[1])


# plt.figure()
# for k in range(0,tp): 
#     plt.subplot(1,tp, k+1)
#     plt.imshow(x_next[0][k].detach().to('cpu').permute([1,2, 0]))
# plt.title(targlist[1])
# Out:
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_default_run_mnist
#  snapshot_model_iter_50000
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_NeuralMstar_neuralM_vanilla
#  snapshot_model_iter_50000

# %% [markdown]
# # Equivariance (this should be higher than prediction error, look over

# %%
equiv_results = {} 
inferred_Ms = {} 
tp = 8
n_cond = 2
#targdir_pathlist = [os.path.join(targpath, targdir) for targdir in targlist] 

for targdir_path in showresults:
    
    Mlist = [] 
    config = load_config(targdir_path)
    
    dataconfig = config['train_data']
    dataconfig['args']['shared_transition'] = 1
    dataconfig['args']['T'] = tp + n_cond
    
    data = yu.load_component(dataconfig)
    train_loader = DataLoader(data, 
                              batch_size=config['batchsize'],
                              shuffle=True,
                              num_workers=config['num_workers'])
    model = yu.load_component(config['model'])
    iterlist = iter_list(targdir_path)
    
    if len(iterlist) == 0:
         print(f"""There is no model trained for {targdir_path}""")
    else:
        maxiter = np.max(iter_list(targdir_path))
        load_model(model, targdir_path, maxiter)
        model = model.eval().to(device)

        # Initialize lazy modules
        images = iter(train_loader).next()
        # Initialize lazy modules
        if type(images) == list:
            images = torch.stack(images)
            images = images.transpose(1, 0)
        
        images = images.to(device)

        if str(type(model)).split(' ')[-1].split('.')[-1].split("'")[0] == 'SeqAENeuralM_latentPredict':
            model.conduct_prediction(images[:, :n_cond], n_rolls=tp)
        else:
            model(images[:, :n_cond])        
        
        with torch.no_grad():
            scores = [] 
            for images in tqdm(train_loader):
                if type(images) == list:
                    images = torch.stack(images)
                    images = images.transpose(1, 0)   
                # n t c w h
                images = images.to(device)
                images_cond = images[:, :n_cond]
                images_target = images[:, n_cond:n_cond+tp]
                
                x_next_perm, M  = ev.predict(images, model, n_cond=n_cond, tp=tp, device=device, swap=True)

                
                l2_losses = []
                for k in range(tp):
                    #l2_loss_t = torch.sqrt(torch.sum((images_target[:, k].to('cpu') - x_next_perm[:, k].to('cpu'))**2))
                    l2_loss_t = torch.sqrt(torch.sum((images_target[:, k].to('cpu') - x_next_perm[:, k].to('cpu'))**2, axis=[1,2,3]))
                    l2_loss_t = torch.mean(l2_loss_t)
                    
                    l2_losses.append(l2_loss_t)
                scores.append(torch.tensor(l2_losses))
                Mlist.append(M)
        
                
        Mlist = torch.cat(Mlist)       
        scores = torch.stack(scores)
        av_score = torch.mean(scores, axis=0)
        av_var = torch.var(scores, axis=0)
        equiv_results[targdir_path] = [av_score, av_var]
        inferred_Ms[targdir_path] = Mlist
# Out:
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:17<00:00, 10.33it/s]
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:17<00:00, 10.27it/s]
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# 100%|██████████| 183/183 [00:17<00:00, 10.24it/s]
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_default_run_mnist
#  snapshot_model_iter_50000
# 100%|██████████| 183/183 [00:09<00:00, 19.51it/s]
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_NeuralMstar_neuralM_vanilla
#  snapshot_model_iter_50000
# 100%|██████████| 183/183 [00:09<00:00, 18.43it/s]

# %%
for mode in list(showresults):
    plt.plot(equiv_results[mode][0], label=mode.split('/')[-1])
    plt.xlabel("tp")
plt.legend(loc=0, bbox_to_anchor=(1.05, 0.5))
plt.title("equivariance")
plt.savefig(os.path.join(jobpath, targdir + 'equivariance.png'))

# %%
tp=8
idx = 0
#jobpath = os.path.join('../jobs/','_'.join(targdir.split('_')[:-1]))


images = data[idx]
if type(images) == list:
    images = torch.stack(images)
    images = images.unsqueeze(0)   
    images= images.to(device)

images_target = images[:, n_cond:n_cond+tp]

    
plt.figure(figsize =(10,2))
for k in range(0,tp):
    plt.subplot(1,tp, k+1)
    plt.imshow(images_target[0][k].detach().to('cpu').permute([1,2, 0]))
    
plt.suptitle(f"""original_target""")
plt.savefig(os.path.join(jobpath, f"""{targdir}_equiv_original.png"""))

for j in range(len(showresults)):
    x_next, M = get_predict(showresults[j], swap=True)
    name = showresults[j].split('/')[-1]
    plt.figure(figsize =(10,2))
    err = 0 
    for k in range(0,tp): 
        plt.subplot(1,tp, k+1)
        plt.imshow(x_next[0][k].detach().to('cpu').permute([1,2, 0]))
        err = err + torch.sum((x_next[0][k].to('cpu') - images_target[0][k].to('cpu'))**2)
    err = err / (k+1)
    plt.suptitle(f"""{name}: mean_equiv_err {err}""")
    plt.savefig(os.path.join(jobpath, f"""{targdir}_equiv_{name}.png"""))
# Out:
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent005_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent01_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220907_latentPredict_0/reg_latent1_reg_obs10_dmodedefault_predictiveTrue
#  snapshot_model_iter_100000
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20220615_default_run_mnist
#  snapshot_model_iter_50000

# %%
x_next[0][k].shape
# Out:
# torch.Size([3, 32, 32])

# %%
os.listdir('/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result')
# Out:
# ['20220825_Mstar_variation_0',
#  '20220901_Mstar_inv_reg_cnn_0',
#  '20220617_default_run_mnist_bg',
#  '20220624_Mstar_longer_tp_neuralM_comm',
#  '20220621_NeuralMstar_bg_neuralM_vanilla',
#  '20220624_Mstar_longer_tp_neuralM_vanilla',
#  '20220830_Mstar_orth_0',
#  '20220826_Mstar_orth_mlp_two_0',
#  '20220831_Mstar_orth_0',
#  '20220630_NeuralMstar_comm_0',
#  '20220830_Mstar_inv_reg_cnn_0',
#  '20220617_NeuralMstar_bg_neuralM_comm',
#  '20220628_NeuralMstar_comm_0',
#  '20220829_Mstar_inv_reg_0',
#  '20220621_NeuralMstar_bg_neuralM_comm',
#  '20220816_so3_various_dat_three_0',
#  '20220621_so3_rcst_so3run',
#  '20220827_Mstar_orth_mlp_two_0',
#  '20220615_default_run_mnist',
#  '20220615_NeuralMstar',
#  '20220615_NeuralMstar_neuralM_vanilla',
#  '20220628_pfkube_try_0',
#  '20220823_sine_dat_0',
#  '20220908_latentPredict_bg_0',
#  '20220701_so3_various_dat_three_0',
#  '20220901_Mstar_orth_0',
#  '20220630_longer_tp_0',
#  '20220829_Mstar_inv_reg_cnn_0',
#  '20220628_so3_idnet_0',
#  '20220611_so3_so3run_rcst',
#  '20220628_so3_various_dat_0',
#  '20220701_so3_various_dat_two_0',
#  '20220611_so3_so3run_rcst_iter',
#  '20220817_so2_dat_0',
#  '20220831_Mstar_inv_reg_cnn_0',
#  '20220701_so3_various_dat_four_0',
#  '20220816_so2_dat_0',
#  '20220624_NeuralMstar_comm_bg_neuralM_vanilla',
#  '20220628_so3_linear_net_0',
#  '20220907_latentPredict_0',
#  '20220624_NeuralMstar_comm_bg_neuralM_comm',
#  '20220630_so3_various_dat_0',
#  '20220511_so3_exp_0',
#  'temp',
#  '20220826_Mstar_orth_0',
#  '20220629_so3_various_dat_0',
#  '20220628_longer_tp_0',
#  '20220824_MstarRemoveXa_0',
#  '20220827_Mstar_orth_mlp_0',
#  '20220611_so3_so3run',
#  '20220817_so3_various_dat_three_0',
#  '20220611_so3',
#  '20220621_default_run_mnist_bg',
#  '20220615_Mstar_comm',
#  '20220617_NeuralMstar_bg_neuralM_vanilla',
#  '20220615_NeuralMstar_neuralM',
#  '20220830_Mstar_orth_mlp_0',
#  '20220621_so3_rcst_so3run_rcst']
