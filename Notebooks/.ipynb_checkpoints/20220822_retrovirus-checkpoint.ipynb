# %%
import os
import sys
from importlib import reload
sys.path.append('../')
sys.path.append('../datasets')
sys.path.append('../models')
from matplotlib import pyplot as plt

import torch
from models import base_networks as bn

import numpy as np

numseq=1
lenseq=15

# %%
reload(bn)
model = bn.Radial_sine()

# checkX = torch.tensor(np.sin(np.linspace(0, 2* np.pi, numseq*lenseq)))
# checkY = torch.tensor(np.cos(np.linspace(0, 2* np.pi, numseq*lenseq)))
# checkZ = torch.zeros(checkX.shape)

# check_dat  = torch.stack([checkX, checkY, checkZ])
# check_dat  = torch.cat([check_dat, check_dat])
# check_dat = check_dat.permute([1,0])
# check_dat = check_dat.reshape(-1 , 60)

zloc = 0

latent_dat = torch.zeros([numseq, lenseq, 6])
for k in range(numseq):
    for j in range(lenseq):
        for m in range(2):
            speed = np.random.normal()
            loc = np.random.normal()
            radius = np.cos(zloc)
            latent_dat[k, j, 3* m + 0] = radius * np.sin(j*speed + loc)
            latent_dat[k, j, 3* m + 1] = radius * np.cos(j*speed + loc)
            latent_dat[k, j, 3* m + 2] = zloc 


print(latent_dat.shape)

xdat = model(latent_dat)
xdat[1 , 1, ]
# Out:
# torch.Size([2, 15, 6])
# > /mnt/vol21/masomatics/ULASclone/models/base_networks.py(192)__call__()
#     190
#     191         pdb.set_trace()
# --> 192         for pos in range(num_blocks):
#     193
#     194             x = dat[:, pos + 0]
#
# ipdb> dat
# tensor([[[-9.5339e-01,  3.0174e-01,  0.0000e+00, -1.3876e-01,  9.9033e-01,
#            0.0000e+00],
#          [ 9.7575e-01,  2.1890e-01,  0.0000e+00, -9.9094e-01,  1.3430e-01,
#            0.0000e+00],
#          [ 9.3399e-01, -3.5730e-01,  0.0000e+00,  8.8069e-01,  4.7368e-01,
#            0.0000e+00],
#          [-2.7329e-02, -9.9963e-01,  0.0000e+00,  9.4648e-01, -3.2276e-01,
#            0.0000e+00],
#          [-1.3942e-01, -9.9023e-01,  0.0000e+00, -9.9850e-01,  5.4725e-02,
#            0.0000e+00],
#          [-9.9956e-01,  2.9813e-02,  0.0000e+00,  9.7227e-01,  2.3388e-01,
#            0.0000e+00],
#          [-6.2628e-01, -7.7959e-01,  0.0000e+00, -1.8054e-01,  9.8357e-01,
#            0.0000e+00],
#          [ 9.8930e-01, -1.4588e-01,  0.0000e+00,  9.3740e-01, -3.4824e-01,
#            0.0000e+00],
#          [-3.5998e-01,  9.3296e-01,  0.0000e+00, -4.5712e-01, -8.8941e-01,
#            0.0000e+00],
#          [-9.7269e-01, -2.3210e-01,  0.0000e+00,  7.1587e-01, -6.9824e-01,
#            0.0000e+00],
#          [ 5.4183e-01,  8.4049e-01,  0.0000e+00,  8.3485e-01,  5.5048e-01,
#            0.0000e+00],
#          [-7.6359e-01, -6.4570e-01,  0.0000e+00,  9.9016e-01, -1.3997e-01,
#            0.0000e+00],
#          [-9.9557e-01, -9.4061e-02,  0.0000e+00, -9.8359e-02,  9.9515e-01,
#            0.0000e+00],
#          [-7.3007e-01, -6.8338e-01,  0.0000e+00, -7.6720e-01, -6.4141e-01,
#            0.0000e+00],
#          [ 2.9564e-02,  9.9956e-01,  0.0000e+00, -2.6867e-02,  9.9964e-01,
#            0.0000e+00]],
#
#         [[ 6.0000e-01,  8.0000e-01,  0.0000e+00, -1.5330e-01,  9.8818e-01,
#            0.0000e+00],
#          [-6.2371e-04,  1.0000e+00,  0.0000e+00,  9.8849e-01, -1.5132e-01,
#            0.0000e+00],
#          [-9.9926e-01, -3.8522e-02,  0.0000e+00,  8.6372e-01,  5.0398e-01,
#            0.0000e+00],
#          [ 8.9389e-01,  4.4828e-01,  0.0000e+00,  5.3588e-01,  8.4429e-01,
#            0.0000e+00],
#          [ 6.5547e-01,  7.5522e-01,  0.0000e+00, -8.6134e-02, -9.9628e-01,
#            0.0000e+00],
#          [ 9.8093e-01, -1.9435e-01,  0.0000e+00, -5.8815e-01, -8.0875e-01,
#            0.0000e+00],
#          [ 6.3098e-01, -7.7580e-01,  0.0000e+00,  2.7081e-02,  9.9963e-01,
#            0.0000e+00],
#          [ 3.6616e-01, -9.3055e-01,  0.0000e+00, -9.7362e-01, -2.2817e-01,
#            0.0000e+00],
#          [-3.6493e-02, -9.9933e-01,  0.0000e+00,  7.5041e-01, -6.6098e-01,
#            0.0000e+00],
#          [ 1.1375e-01,  9.9351e-01,  0.0000e+00,  5.5176e-01, -8.3400e-01,
#            0.0000e+00],
#          [ 2.0306e-01,  9.7917e-01,  0.0000e+00, -8.9222e-01, -4.5160e-01,
#            0.0000e+00],
#          [ 9.8030e-01, -1.9752e-01,  0.0000e+00, -9.6720e-01, -2.5401e-01,
#            0.0000e+00],
#          [ 3.3356e-01,  9.4273e-01,  0.0000e+00, -8.3483e-01,  5.5050e-01,
#            0.0000e+00],
#          [-7.9635e-01, -6.0484e-01,  0.0000e+00, -6.5323e-01,  7.5716e-01,
#            0.0000e+00],
#          [ 3.3337e-01,  9.4280e-01,  0.0000e+00, -9.9745e-01, -7.1307e-02,
#            0.0000e+00]]])

# %%
xdat.shape
# Out:
# torch.Size([1000, 15, 6])

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')




#latent_dat = check_dat

myslice = 0
pos= 1

shift= 0
for k in range(20):

    batch = latent_dat[:, myslice, pos*3:(pos+1)*3]
    xbatch = xdat[:, myslice, pos*3:(pos+1)*3]


    
    ax.scatter(batch[:, 0], batch[:, 1], batch[:, 2], color= 'blue')

    ax.scatter(xbatch[:, 0], xbatch[:, 1], xbatch[:, 2], color= 'red')

# %%
xdat[1 , 1, ]
# Out:
# tensor([13.0700,  4.2272,     nan, 13.0324,  3.4439,     nan])

# %%
check_dat_show.shape
# Out:
# torch.Size([1500, 10, 6])
