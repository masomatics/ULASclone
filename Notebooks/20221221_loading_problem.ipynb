# %%
import torch
import sys
sys.path.append('../')
sys.path.append('../models')
sys.path.append('../datasets')
from torch.utils.data import DataLoader
from utils import evaluations as ev



from source import yaml_utils as yu
import os



from utils import notebook_utils as nu


targdir_path = '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20221221_glasso_mse_0/nameSequentialMNIST_double_detach1_modeexact_lr01'

targdir_path = '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20221221_glasso_mse_0/nameSequentialMNIST_double_detach0_modeglasso_lr01'

config = nu.load_config(targdir_path)
maxiter=100000
model_config = config['model']

model = yu.load_component(model_config)
nu.load_model(model, targdir_path, maxiter)
# Out:
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20221221_glasso_mse_0/nameSequentialMNIST_double_detach0_modeglasso_lr01
#  snapshot_model_iter_100000

# %%
config
# Out:
# {'T_cond': 2,
#  'T_pred': 1,
#  'batchsize': 32,
#  'config_path': './configs/mnist/lstsq/lstsq_inner.yml',
#  'log_dir': '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20221221_glasso_mse_0/nameSequentialMNIST_double_detach0_modeglasso_lr01',
#  'lr': 0.0003,
#  'manager_snapshot_freq': 100000,
#  'max_iteration': 100000,
#  'model': {'args': {'ch_x': 3,
#    'detachM': 0,
#    'dim_a': 16,
#    'dim_m': 256,
#    'inner_args': {'batchsize': 32,
#     'beta': 0,
#     'detach': 0,
#     'lr': 0.1,
#     'mode': 'glasso',
#     'normalize': 0,
#     'num_loops': 20,
#     'temperature': 1,
#     'dim_a': 16},
#    'k': 2.0,
#    'predictive': True},
#   'fn': './models/seqae.py',
#   'name': 'SeqAELSTSQ_inner'},
#  'model_snapshot_freq': 100000,
#  'num_workers': 2,
#  'reg': {'reg_bd': 'None', 'reg_orth': 'None'},
#  'report_freq': 1000,
#  'seed': 1,
#  'train_data': {'args': {'T': 3,
#    'backgrnd': False,
#    'fixpos': True,
#    'max_T': 9,
#    'max_angle_velocity_ratio': [-0.5, 0.5],
#    'max_color_velocity_ratio': [-0.5, 0.5],
#    'only_use_digit4': True,
#    'pair_transition': False,
#    'root': '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/datasets/MNIST',
#    'same_object': False,
#    'train': True},
#   'fn': './datasets/seq_mnist.py',
#   'name': 'SequentialMNIST_double'},
#  'training_loop': {'args': {'lr_decay_iter': 40000, 'reconst_iter': 0},
#   'fn': './training_loops.py',
#   'name': 'loop_seqmodel'}}

# %%
tp=10
n_cond=2
dataconfig = config['train_data']
dataconfig['args']['T'] = tp + n_cond
try:
    # IF double dataset, we work with same objects
    if dataconfig['name'] == 'SequentialMNIST_double':
        dataconfig['args']['train'] = True
    else:
        dataconfig['args']['train'] = False
except:
    print("Not working with the pair dataset")
dataconfig['args']['max_T'] = tp + n_cond


data = yu.load_component(dataconfig)


train_loader = DataLoader(data,
                          batch_size=16,
                          shuffle=True,
                          num_workers=config['num_workers'])
# Out:
# /usr/local/lib/python3.8/site-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
ev.prediction_evaluation([targdir_path], device =0,
                           n_cond=2, tp=1, repeats=1,
                           predictive=False,reconstructive = False)
# Out:
# {'args': {'T': 3, 'backgrnd': False, 'fixpos': True, 'max_T': 3, 'max_angle_velocity_ratio': [-0.5, 0.5], 'max_color_velocity_ratio': [-0.5, 0.5], 'only_use_digit4': True, 'pair_transition': False, 'root': '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/datasets/MNIST', 'same_object': False, 'train': True}, 'fn': './datasets/seq_mnist.py', 'name': 'SequentialMNIST_double'}
# /mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20221221_glasso_mse_0/nameSequentialMNIST_double_detach0_modeglasso_lr01
#  snapshot_model_iter_100000
#   1%|          | 1/183 [00:00<01:44,  1.74it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
#   3%|▎         | 5/183 [00:00<00:23,  7.51it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
#   4%|▍         | 7/183 [00:00<00:18,  9.44it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
#   6%|▌         | 11/183 [00:01<00:13, 12.62it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
#   8%|▊         | 15/183 [00:01<00:11, 14.36it/s]
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#   9%|▉         | 17/183 [00:01<00:10, 15.67it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#  11%|█▏        | 21/183 [00:01<00:10, 15.30it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#  14%|█▎        | 25/183 [00:02<00:10, 15.05it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#  15%|█▍        | 27/183 [00:02<00:10, 15.14it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#  17%|█▋        | 31/183 [00:02<00:10, 14.63it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#  18%|█▊        | 33/183 [00:02<00:10, 14.64it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
#  20%|██        | 37/183 [00:02<00:09, 15.39it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
#  21%|██▏       | 39/183 [00:03<00:09, 15.34it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
#  23%|██▎       | 43/183 [00:03<00:09, 15.28it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
#  25%|██▍       | 45/183 [00:03<00:09, 15.31it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#  26%|██▌       | 47/183 [00:03<00:08, 15.66it/s]
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# inner_loss nan
# ----------
#  26%|██▌       | 48/183 [00:03<00:10, 12.53it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3503/3572080410.py in <module>
# ----> 1 ev.prediction_evaluation([targdir_path], device =0,
#       2                            n_cond=2, tp=1, repeats=1,
#       3                            predictive=False,reconstructive = False)
#
# /mnt/vol21/masomatics/ULASclone/utils/evaluations.py in prediction_evaluation(targdir_pathlist, device, n_cond, tp, repeats, predictive, reconstructive)
#     133                         else:
#     134                             images_target = images[:, n_cond:n_cond + tp]
# --> 135                         x_next, M = predict(images, model, n_cond=n_cond,
#     136                                                tp=tp, device=device,
#     137                                                predictive=predictive,
#
# /mnt/vol21/masomatics/ULASclone/utils/evaluations.py in predict(images, model, n_cond, tp, device, swap, predictive, reconstructive)
#      41         xs0 = images[:, [0]].to('cpu')
#      42     else:
# ---> 43         H = model.encode(images_cond[:, -1:])[:, 0] # n s a
#      44         xs0 = []
#      45         if reconstructive:
#
# /mnt/vol21/masomatics/ULASclone/models/seqae.py in encode(self, xs)
#      61
#      62     def encode(self, xs):
# ---> 63         H = self._encode_base(xs, self.enc)
#      64         # batch x time x flatten_dimen
#      65         H = torch.reshape(
#
# /mnt/vol21/masomatics/ULASclone/models/seqae.py in _encode_base(self, xs, enc)
#      54         shape = xs.shape
#      55         x = torch.reshape(xs, (shape[0] * shape[1], *shape[2:]))
# ---> 56         H = enc(x)
#      57         #batch x time x flatten_dimen
#      58         H = torch.reshape(
#
# /mnt/vol21/masomatics/ULASclone/models/base_networks.py in __call__(self, x)
#      50     def __call__(self, x):
#      51         h = x
# ---> 52         h = self.phi(h)
#      53         h = h.reshape(h.shape[0], -1)
#      54         h = self.linear(h)
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     437                             weight, bias, self.stride,
#     438                             _pair(0), self.dilation, self.groups)
# --> 439         return F.conv2d(input, weight, bias, self.stride,
#     440                         self.padding, self.dilation, self.groups)
#     441
#
# KeyboardInterrupt:

# %%
output.requires_grad
# Out:
# True

# %%
import copy
config_two = copy.deepcopy(config)

# %%
import functools
import yaml

alteration={'model.args.inner_args.num_loops':'40'}

# %%
def alter_config(config, alteration):
    config_two = copy.deepcopy(config)
    for key in alteration.keys():
        module, new_value = key, alteration[key]
        keys = module.split('.')
        target = functools.reduce(dict.__getitem__, keys[:-1], config_two)
        if keys[-1] in target.keys():
            target[keys[-1]] = yaml.safe_load(new_value)
        else:
            raise ValueError('The following key is not defined in the config file:{}', keys)
    return config_two

# %%
from importlib import reload
reload(yu)
yu.alter_config(config, alteration)
# Out:
# {'T_cond': 2,
#  'T_pred': 1,
#  'batchsize': 32,
#  'config_path': './configs/mnist/lstsq/lstsq_inner.yml',
#  'log_dir': '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/result/20221221_glasso_mse_0/nameSequentialMNIST_double_detach0_modeglasso_lr01',
#  'lr': 0.0003,
#  'manager_snapshot_freq': 100000,
#  'max_iteration': 100000,
#  'model': {'args': {'ch_x': 3,
#    'detachM': 0,
#    'dim_a': 16,
#    'dim_m': 256,
#    'inner_args': {'batchsize': 32,
#     'beta': 0,
#     'detach': 0,
#     'lr': 0.1,
#     'mode': 'glasso',
#     'normalize': 0,
#     'num_loops': 40,
#     'temperature': 1,
#     'dim_a': 16},
#    'k': 2.0,
#    'predictive': True},
#   'fn': './models/seqae.py',
#   'name': 'SeqAELSTSQ_inner'},
#  'model_snapshot_freq': 100000,
#  'num_workers': 2,
#  'reg': {'reg_bd': 'None', 'reg_orth': 'None'},
#  'report_freq': 1000,
#  'seed': 1,
#  'train_data': {'args': {'T': 3,
#    'backgrnd': False,
#    'fixpos': True,
#    'max_T': 9,
#    'max_angle_velocity_ratio': [-0.5, 0.5],
#    'max_color_velocity_ratio': [-0.5, 0.5],
#    'only_use_digit4': True,
#    'pair_transition': False,
#    'root': '/mnt/nfs-mnj-hot-01/tmp/masomatics/block_diag/datasets/MNIST',
#    'same_object': False,
#    'train': True},
#   'fn': './datasets/seq_mnist.py',
#   'name': 'SequentialMNIST_double'},
#  'training_loop': {'args': {'lr_decay_iter': 40000, 'reconst_iter': 0},
#   'fn': './training_loops.py',
#   'name': 'loop_seqmodel'}}

# %%
keys[:-1]
# Out:
# ['model', 'args', 'inner_args']
